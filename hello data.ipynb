# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
path = 'data/x_train.csv'
data = pd.read_csv(path, sep=';', na_values='?')

# %%
data.head()
# Out:
#    maxPlayerLevel  numberOfAttemptedLevels  attemptsOnTheHighestLevel  \
# 0              39                       10                          3
# 1              21                       22                         19
# 2               5                        6                          1
# 3              21                        2                          5
# 4               4                        5                          1
#
#    totalNumOfAttempts  averageNumOfTurnsPerCompletedLevel  \
# 0                  17                           24.444444
# 1                  55                           17.045455
# 2                   6                            8.400000
# 3                   6                           19.000000
# 4                   5                            9.600000
#
#    doReturnOnLowerLevels  numberOfBoostersUsed  fractionOfUsefullBoosters  \
# 0                      1                     5                   0.400000
# 1                      1                     6                   0.333333
# 2                      0                     1                   1.000000
# 3                      0                     1                   0.000000
# 4                      0                     1                   1.000000
#
#    totalScore  totalBonusScore  totalStarsCount  numberOfDaysActuallyPlayed
# 0     2650000             1375               21                           2
# 1     5614000             3825               51                           4
# 2      857000             1150               14                           1
# 3      120000                0                1                           1
# 4      857000             1075               12                           1

# %%
if data.shape[0] == data.describe().loc['count'].min():
    print('Отсутствуют не заданные признаки')
# Out:
# Отсутствуют не заданные признаки

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']

if len(categorical_columns) == 0:
    print('Отсутствуют котегориальные признаки')
# Out:
# Отсутствуют котегориальные признаки

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(data, alpha=0.05, figsize=(10, 10));

# %%
data.corr()
# Out:
#                                     maxPlayerLevel  numberOfAttemptedLevels  \
# maxPlayerLevel                            1.000000                 0.616157
# numberOfAttemptedLevels                   0.616157                 1.000000
# attemptsOnTheHighestLevel                 0.472142                 0.300797
# totalNumOfAttempts                        0.757854                 0.836398
# averageNumOfTurnsPerCompletedLevel        0.683706                 0.531197
# doReturnOnLowerLevels                     0.368297                 0.290636
# numberOfBoostersUsed                      0.675955                 0.881915
# fractionOfUsefullBoosters                 0.126235                 0.332887
# totalScore                                0.570234                 0.979954
# totalBonusScore                           0.551366                 0.989014
# totalStarsCount                           0.579593                 0.993779
# numberOfDaysActuallyPlayed                0.793385                 0.663450
#
#                                     attemptsOnTheHighestLevel  \
# maxPlayerLevel                                       0.472142
# numberOfAttemptedLevels                              0.300797
# attemptsOnTheHighestLevel                            1.000000
# totalNumOfAttempts                                   0.532032
# averageNumOfTurnsPerCompletedLevel                   0.277072
# doReturnOnLowerLevels                                0.197035
# numberOfBoostersUsed                                 0.389465
# fractionOfUsefullBoosters                           -0.041700
# totalScore                                           0.277326
# totalBonusScore                                      0.264804
# totalStarsCount                                      0.281343
# numberOfDaysActuallyPlayed                           0.524109
#
#                                     totalNumOfAttempts  \
# maxPlayerLevel                                0.757854
# numberOfAttemptedLevels                       0.836398
# attemptsOnTheHighestLevel                     0.532032
# totalNumOfAttempts                            1.000000
# averageNumOfTurnsPerCompletedLevel            0.509510
# doReturnOnLowerLevels                         0.391969
# numberOfBoostersUsed                          0.836706
# fractionOfUsefullBoosters                     0.128843
# totalScore                                    0.798051
# totalBonusScore                               0.795570
# totalStarsCount                               0.808989
# numberOfDaysActuallyPlayed                    0.846448
#
#                                     averageNumOfTurnsPerCompletedLevel  \
# maxPlayerLevel                                                0.683706
# numberOfAttemptedLevels                                       0.531197
# attemptsOnTheHighestLevel                                     0.277072
# totalNumOfAttempts                                            0.509510
# averageNumOfTurnsPerCompletedLevel                            1.000000
# doReturnOnLowerLevels                                         0.250261
# numberOfBoostersUsed                                          0.543847
# fractionOfUsefullBoosters                                     0.457168
# totalScore                                                    0.499681
# totalBonusScore                                               0.489411
# totalStarsCount                                               0.514770
# numberOfDaysActuallyPlayed                                    0.555594
#
#                                     doReturnOnLowerLevels  \
# maxPlayerLevel                                   0.368297
# numberOfAttemptedLevels                          0.290636
# attemptsOnTheHighestLevel                        0.197035
# totalNumOfAttempts                               0.391969
# averageNumOfTurnsPerCompletedLevel               0.250261
# doReturnOnLowerLevels                            1.000000
# numberOfBoostersUsed                             0.320439
# fractionOfUsefullBoosters                        0.071646
# totalScore                                       0.310218
# totalBonusScore                                  0.271397
# totalStarsCount                                  0.288803
# numberOfDaysActuallyPlayed                       0.383024
#
#                                     numberOfBoostersUsed  \
# maxPlayerLevel                                  0.675955
# numberOfAttemptedLevels                         0.881915
# attemptsOnTheHighestLevel                       0.389465
# totalNumOfAttempts                              0.836706
# averageNumOfTurnsPerCompletedLevel              0.543847
# doReturnOnLowerLevels                           0.320439
# numberOfBoostersUsed                            1.000000
# fractionOfUsefullBoosters                       0.203519
# totalScore                                      0.854263
# totalBonusScore                                 0.851824
# totalStarsCount                                 0.862254
# numberOfDaysActuallyPlayed                      0.751712
#
#                                     fractionOfUsefullBoosters  totalScore  \
# maxPlayerLevel                                       0.126235    0.570234
# numberOfAttemptedLevels                              0.332887    0.979954
# attemptsOnTheHighestLevel                           -0.041700    0.277326
# totalNumOfAttempts                                   0.128843    0.798051
# averageNumOfTurnsPerCompletedLevel                   0.457168    0.499681
# doReturnOnLowerLevels                                0.071646    0.310218
# numberOfBoostersUsed                                 0.203519    0.854263
# fractionOfUsefullBoosters                            1.000000    0.328287
# totalScore                                           0.328287    1.000000
# totalBonusScore                                      0.358474    0.985111
# totalStarsCount                                      0.358219    0.986423
# numberOfDaysActuallyPlayed                           0.058929    0.617847
#
#                                     totalBonusScore  totalStarsCount  \
# maxPlayerLevel                             0.551366         0.579593
# numberOfAttemptedLevels                    0.989014         0.993779
# attemptsOnTheHighestLevel                  0.264804         0.281343
# totalNumOfAttempts                         0.795570         0.808989
# averageNumOfTurnsPerCompletedLevel         0.489411         0.514770
# doReturnOnLowerLevels                      0.271397         0.288803
# numberOfBoostersUsed                       0.851824         0.862254
# fractionOfUsefullBoosters                  0.358474         0.358219
# totalScore                                 0.985111         0.986423
# totalBonusScore                            1.000000         0.997357
# totalStarsCount                            0.997357         1.000000
# numberOfDaysActuallyPlayed                 0.606864         0.626330
#
#                                     numberOfDaysActuallyPlayed
# maxPlayerLevel                                        0.793385
# numberOfAttemptedLevels                               0.663450
# attemptsOnTheHighestLevel                             0.524109
# totalNumOfAttempts                                    0.846448
# averageNumOfTurnsPerCompletedLevel                    0.555594
# doReturnOnLowerLevels                                 0.383024
# numberOfBoostersUsed                                  0.751712
# fractionOfUsefullBoosters                             0.058929
# totalScore                                            0.617847
# totalBonusScore                                       0.606864
# totalStarsCount                                       0.626330
# numberOfDaysActuallyPlayed                            1.000000

# %% [markdown]
# Есть сильно коррелирующие данные
